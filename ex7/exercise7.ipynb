# %% [markdown]
# # <span style="color:green"> Numerical Simulation Laboratory (NSL) </span>
# ## <span style="color:blue">  Numerical exercises 7</span>

# %% [markdown]
# Luca Maria Colombo Gomez - Matr:

# %% [markdown]
# ### Exercise 07.1
#
# Make pictures with a python script of the autocorrelation functions of U/N and P to obtain the Monte Carlo correlation time via a fit with an exponential function.

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats
from scipy.optimize import curve_fit

# %% [markdown]
# import the modules neeeded and plot the instant values

# %%
plt.figure(figsize=(7,5))
plt.title('Instant potential energy')
plt.ylabel('U/N')
plt.xlabel('MC Steps')

t, y= np.loadtxt("7.1/output/epot.instant.solid", usecols=(0,1), unpack='true')
plt.plot(t,y, label='gas')

t, y= np.loadtxt("7.1/output/epot.instant.liquid", usecols=(0,1), unpack='true')
plt.plot(t,y, label='liquid')

t, y= np.loadtxt("7.1/output/epot.instant.gas", usecols=(0,1), unpack='true')
plt.plot(t,y, label='solid')

plt.legend()
plt.show()
